# %%
import matplotlib.pyplot as plt
from pathlib import Path

# Data: Fraction of labeled data vs. Macro F1 scores for three methods (label ratio is not actively reserved when using the p fraction of labeled data)

# PROJECT_ROOT = Path(__file__).resolve().parents[1] #works only for python scripts
PROJECT_ROOT = Path.cwd().parent
print(PROJECT_ROOT)
TARGET_DIR = PROJECT_ROOT / "plots"

p = [0.01, 0.05, 0.1, 0.2, 0.5, 1.0]
# Out:
# c:\Users\leand\projects\sem-proj

# %%
### run if you want the context-free model plot ###
### context-free model, these results are from the powerpoint SSL result week 12_01-19_01.pptx ###
p = [0.01, 0.05, 0.1, 0.2, 0.5, 1.0]
mf1_linprobe = [0.4850, 0.5659, 0.5652, 0.5789, 0.5953, 0.5977]
mf1_finetuned = [0.5219, 0.5711, 0.6261, 0.6395, 0.6368, 0.6443]
mf1_fullysuperv = [0.4974, 0.5405, 0.5567, 0.6091, 0.6339, 0.6547]

# absolute values plot
plt.figure(figsize=(10, 6))
plt.plot(p, mf1_linprobe, marker='+', linewidth=2, markersize=8, label='Linear Probing', color='blue')
plt.plot(p, mf1_finetuned, marker='x', linewidth=2, markersize=8, label='SSL Fine-Tuning', color='green')
plt.plot(p, mf1_fullysuperv, marker='o', linewidth=2, markersize=8, label='Fully-Supervised End-to-End', color='red')
plt.xlabel('\nFraction of Labeled Data\n', fontsize=18)
plt.ylabel('\nMacro F1 Score\n', fontsize=18)
# plt.title('Linear Probing vs. SSL Fine-Tuning vs. Fully-Supervised End-to-End\n', fontsize=18)
plt.legend(fontsize=16)
plt.tick_params(axis='both', labelsize=16)
plt.tight_layout()
plt.grid(True)
# plt.show()
plt.savefig(TARGET_DIR / 'lin-probe_vs_finetuned_vs_fullysuperv-endtoend_mf1.pdf', dpi=300, bbox_inches='tight')

# relative improvement plot
p = [0.01, 0.05, 0.1, 0.2, 0.5, 1.0]
p = [x * 100 for x in p]  # convert to percentage
rel_impr_finetuned =[]
for fine, fully in zip(mf1_finetuned, mf1_fullysuperv):
    rel_impr_finetuned.append((fine - fully) / fully * 100)
plt.figure(figsize=(10, 6))
plt.plot(p, rel_impr_finetuned, marker='x', linewidth=2, markersize=8, color='green')
plt.xlabel('\nPercentage of labeled training data used (%)\n', fontsize=18)
# plt.xlabel('\nFraction of Labeled Data\n', fontsize=18)
plt.ylabel('\nRelative Improvement MF1 Score (%)\n', fontsize=18)
plt.tick_params(axis='both', labelsize=16)
plt.tight_layout()
plt.grid(True)
# plt.show()
plt.savefig(TARGET_DIR / 'finetuned_vs_fullysuperv_rel_impr_mf1_ctx-free.pdf', dpi=300, bbox_inches='tight')

# %%
### run if you want the context-free model plot (N1 only) ###
### context-free model, these results are from the powerpoint SSL result week 12_01-19_01.pptx ###
p = [0.01, 0.05, 0.1, 0.2, 0.5, 1.0]
p = [x * 100 for x in p]  # convert to percentage
n1_linprobe = [0.163, 0.1896, 0.1875, 0.2312, 0.2283, 0.236]
n1_finetuned = [0.1818, 0.2065, 0.2504, 0.2812, 0.2721, 0.2793]
n1_fullysuperv = [0.1576, 0.1887, 0.2047, 0.2738, 0.2773, 0.2879]

plt.figure(figsize=(10, 6))
plt.plot(p, n1_linprobe, marker='+', linewidth=2, markersize=8, label='Linear Probing', color='blue')
plt.plot(p, n1_finetuned, marker='x', linewidth=2, markersize=8, label='SSL Fine-Tuning', color='green')
plt.plot(p, n1_fullysuperv, marker='o', linewidth=2, markersize=8, label='Fully-Supervised End-to-End', color='red')
plt.xlabel('\nPercentage of Labeled Data Used (%)\n', fontsize=18)
plt.ylabel('\nF1 Score Sleep Stage N1\n', fontsize=18)
# plt.title('Linear Probing vs. SSL Fine-Tuning vs. Fully-Supervised End-to-End\n', fontsize=18)
plt.legend(fontsize=16)
plt.tick_params(axis='both', labelsize=16)
plt.tight_layout()
plt.grid(True)
# plt.show()
plt.savefig(TARGET_DIR / 'lin-probe_vs_finetuned_vs_fullysuperv-endtoend_n1.pdf', dpi=300, bbox_inches='tight')

# relative improvement plot for N1
p = [0.01, 0.05, 0.1, 0.2, 0.5, 1.0]
p = [x * 100 for x in p]  # convert to percentage
rel_impr_finetuned_n1 =[]
for fine, fully in zip(n1_finetuned, n1_fullysuperv):
    rel_impr_finetuned_n1.append((fine - fully) / fully * 100)
plt.figure(figsize=(10, 6))
plt.plot(p, rel_impr_finetuned_n1, marker='x', linewidth=2, markersize=8, color='green')
plt.xlabel('\nPercentage of labeled training data used (%)\n', fontsize=17)
plt.ylabel('\nRelative Improvement F1 Score N1 (%)\n', fontsize=17)
plt.tick_params(axis='both', labelsize=16)
plt.tight_layout()
plt.grid(True)
# plt.show()
plt.savefig(TARGET_DIR / 'finetuned_vs_fullysuperv_rel_impr_n1_ctx-free.pdf', dpi=300, bbox_inches='tight')

# %%
### run if you want the context-sensitive model plot (GRU with L=20, stride=5)###
### context-sensitive model, these results are from the powerpoint SSL result week 12_01-19_01.pptx (!context-sensitive!) ###
p = [0.01, 0.05, 0.1, 0.2, 0.5, 1.0]
p = [x * 100 for x in p]  # convert to percentage
mf1_finetuned = [0.4507, 0.6173, 0.6845, 0.6795, 0.6957, 0.6969]
mf1_fullysuperv = [0.4507, 0.5295, 0.5451, 0.6181, 0.6495, 0.6973]
plt.figure(figsize=(10, 6))
plt.plot(p, mf1_finetuned, marker='x', linewidth=2, markersize=8, label='SSL Fine-Tuning', color='green')
plt.plot(p, mf1_fullysuperv, marker='o', linewidth=2, markersize=8, label='Fully-Supervised End-to-End', color='red')
plt.xlabel('\nPercentage of Labeled Data Used (%)\n', fontsize=18)
plt.ylabel('\nMacro F1 Score\n', fontsize=18)
# plt.title('Linear Probing vs. SSL Fine-Tuning vs. Fully-Supervised End-to-End\n', fontsize=18)
plt.legend(fontsize=16)
plt.tick_params(axis='both', labelsize=16)
plt.tight_layout()
plt.grid(True)
# plt.show()
plt.savefig(TARGET_DIR / 'finetuned_vs_fullysuperv-endtoend_mf1_ctx-sens.pdf', dpi=300, bbox_inches='tight')

# relative improvement plot
p = [0.01, 0.05, 0.1, 0.2, 0.5, 1.0]
p = [x * 100 for x in p]  # convert to percentage
rel_impr_finetuned =[]
for fine, fully in zip(mf1_finetuned, mf1_fullysuperv):
    rel_impr_finetuned.append((fine - fully) / fully * 100)
plt.figure(figsize=(10, 6))
plt.plot(p, rel_impr_finetuned, marker='x', linewidth=2, markersize=8, color='green')
plt.xlabel('\nPercentage of labeled training data used (%)\n', fontsize=18)
plt.ylabel('\nRelative Improvement MF1 Score (%)\n', fontsize=18)
plt.tick_params(axis='both', labelsize=16)
plt.tight_layout()
plt.grid(True)
# plt.show()
plt.savefig(TARGET_DIR / 'finetuned_vs_fullysuperv_rel_impr_mf1_ctx-sens.pdf', dpi=300, bbox_inches='tight')
