# %%
# run this cell in either case to import all necessary libraries
import matplotlib.pyplot as plt
from pathlib import Path
import json

# Data: Fraction of labeled data vs. Macro F1 scores for three methods (label ratio is not actively reserved when using the p fraction of labeled data)

# PROJECT_ROOT = Path(__file__).resolve().parents[1] #works only for python scripts
PROJECT_ROOT = Path.cwd().parent
print(PROJECT_ROOT)
TARGET_DIR = PROJECT_ROOT / "plots"

p = [0.01, 0.05, 0.1, 0.2, 0.5, 1.0]
# Out:
# c:\Users\leand\projects\sem-proj

# %%
### run if you want the context-free model plot STAGE1 ###
### context-free model, these results are from the powerpoint SSL results.pptx (stage1) ###
p = [0.01, 0.05, 0.1, 0.2, 0.5, 1.0]
mf1_linprobe = [0.4850, 0.5659, 0.5652, 0.5789, 0.5953, 0.5977]
mf1_finetuned = [0.5219, 0.5711, 0.6261, 0.6395, 0.6368, 0.6443]
mf1_fullysuperv = [0.4974, 0.5405, 0.5567, 0.6091, 0.6339, 0.6547]

# absolute values plot
plt.figure(figsize=(10, 6))
plt.plot(p, mf1_linprobe, marker='+', linewidth=2, markersize=8, label='SSL Pretrain Linear Probing', color='blue')
plt.plot(p, mf1_finetuned, marker='x', linewidth=2, markersize=8, label='SSL Pretrain + FT', color='green')
plt.plot(p, mf1_fullysuperv, marker='o', linewidth=2, markersize=8, label='Supervised from Scratch', color='red')
plt.xlabel('\nPercentage of labeled training data (%)\n', fontsize=18)
plt.ylabel('\nMacro F1 Score\n', fontsize=18)
# plt.title('Linear Probing vs. SSL Fine-Tuning vs. Fully-Supervised End-to-End\n', fontsize=18)
plt.legend(fontsize=16)
plt.tick_params(axis='both', labelsize=16)
plt.tight_layout()
plt.grid(True)
# plt.show()
plt.savefig(TARGET_DIR / 'lin-probe_vs_finetuned_vs_fullysupervised_mf1_ctx-free_stage1.pdf', dpi=300, bbox_inches='tight')

# relative improvement plot stage1
p = [0.01, 0.05, 0.1, 0.2, 0.5, 1.0]
p = [x * 100 for x in p]  # convert to percentage
rel_impr_finetuned =[]
for fine, fully in zip(mf1_finetuned, mf1_fullysuperv):
    rel_impr_finetuned.append((fine - fully) / fully * 100)
plt.figure(figsize=(10, 6))
plt.plot(p, rel_impr_finetuned, marker='x', linewidth=2, markersize=8, color='green')
plt.xlabel('\nPercentage of labeled training data (%)\n', fontsize=18)
# plt.xlabel('\nFraction of Labeled Data\n', fontsize=18)
plt.ylabel('\nRelative Improvement MF1 Score (%)\n', fontsize=18)
plt.tick_params(axis='both', labelsize=16)
plt.tight_layout()
plt.grid(True)
# plt.show()
plt.savefig(TARGET_DIR / 'finetuned_vs_fullysupervised_rel_impr_mf1_ctx-free_stage1.pdf', dpi=300, bbox_inches='tight')

# %%
### run if you want the context-free model plot (N1 only) STAGE1 ###
### context-free model, these results are from the powerpoint SSL results.pptx (stage1)###
p = [0.01, 0.05, 0.1, 0.2, 0.5, 1.0]
p = [x * 100 for x in p]  # convert to percentage
n1_linprobe = [0.163, 0.1896, 0.1875, 0.2312, 0.2283, 0.236]
n1_finetuned = [0.1818, 0.2065, 0.2504, 0.2812, 0.2721, 0.2793]
n1_fullysuperv = [0.1576, 0.1887, 0.2047, 0.2738, 0.2773, 0.2879]

plt.figure(figsize=(10, 6))
plt.plot(p, n1_linprobe, marker='+', linewidth=2, markersize=8, label='Linear Probing', color='blue')
plt.plot(p, n1_finetuned, marker='x', linewidth=2, markersize=8, label='SSL Pretrain + FT', color='green')
plt.plot(p, n1_fullysuperv, marker='o', linewidth=2, markersize=8, label='Supervised from Scratch', color='red')
plt.xlabel('\nPercentage of labeled training data (%)\n', fontsize=18)
plt.ylabel('\nF1 Score Sleep Stage N1\n', fontsize=18)
# plt.title('Linear Probing vs. SSL Fine-Tuning vs. Fully-Supervised End-to-End\n', fontsize=18)
plt.legend(fontsize=16)
plt.tick_params(axis='both', labelsize=16)
plt.tight_layout()
plt.grid(True)
# plt.show()
plt.savefig(TARGET_DIR / 'lin-probe_vs_finetuned_vs_fullysupervised_n1_stage1.pdf', dpi=300, bbox_inches='tight')

# relative improvement plot for N1 STAGE1
p = [0.01, 0.05, 0.1, 0.2, 0.5, 1.0]
p = [x * 100 for x in p]  # convert to percentage
rel_impr_finetuned_n1 =[]
for fine, fully in zip(n1_finetuned, n1_fullysuperv):
    rel_impr_finetuned_n1.append((fine - fully) / fully * 100)
plt.figure(figsize=(10, 6))
plt.plot(p, rel_impr_finetuned_n1, marker='x', linewidth=2, markersize=8, color='green')
plt.xlabel('\nPercentage of labeled training data (%)\n', fontsize=17)
plt.ylabel('\nRelative Improvement F1 Score N1 (%)\n', fontsize=17)
plt.tick_params(axis='both', labelsize=16)
plt.tight_layout()
plt.grid(True)
# plt.show()
plt.savefig(TARGET_DIR / 'finetuned_vs_fullysupervised_rel_impr_n1_ctx-free_stage1.pdf', dpi=300, bbox_inches='tight')

# %%
### run if you want the context-sensitive model plot STAGE1 (GRU with L=20, stride=5)###
### context-sensitive model, these results are from the powerpoint SSL result week 12_01-19_01.pptx (!context-sensitive!) ###
p = [0.01, 0.05, 0.1, 0.2, 0.5, 1.0]
p = [x * 100 for x in p]  # convert to percentage
mf1_finetuned = [0.4507, 0.6173, 0.6845, 0.6795, 0.6957, 0.6969]
mf1_fullysuperv = [0.4507, 0.5295, 0.5451, 0.6181, 0.6495, 0.6973]
plt.figure(figsize=(10, 6))
plt.plot(p, mf1_finetuned, marker='x', linewidth=2, markersize=8, label='SSL Pretrain + FT', color='green')
plt.plot(p, mf1_fullysuperv, marker='o', linewidth=2, markersize=8, label='Supervised from Scratch', color='red')
plt.xlabel('\nPercentage of labeled training data (%)\n', fontsize=18)
plt.ylabel('\nMacro F1 Score\n', fontsize=18)
# plt.title('Linear Probing vs. SSL Fine-Tuning vs. Fully-Supervised End-to-End\n', fontsize=18)
plt.legend(fontsize=16)
plt.tick_params(axis='both', labelsize=16)
plt.tight_layout()
plt.grid(True)
# plt.show()
plt.savefig(TARGET_DIR / 'finetuned_vs_fullysupervised_mf1_ctx-sens_stage1.pdf', dpi=300, bbox_inches='tight')

# relative improvement plot
p = [0.01, 0.05, 0.1, 0.2, 0.5, 1.0]
p = [x * 100 for x in p]  # convert to percentage
rel_impr_finetuned =[]
for fine, fully in zip(mf1_finetuned, mf1_fullysuperv):
    rel_impr_finetuned.append((fine - fully) / fully * 100)
plt.figure(figsize=(10, 6))
plt.plot(p, rel_impr_finetuned, marker='x', linewidth=2, markersize=8, color='green')
plt.xlabel('\nPercentage of labeled training data (%)\n', fontsize=18)
plt.ylabel('\nRelative Improvement MF1 Score (%)\n', fontsize=18)
plt.tick_params(axis='both', labelsize=16)
plt.tight_layout()
plt.grid(True)
# plt.show()
plt.savefig(TARGET_DIR / 'finetuned_vs_fullysupervised_rel_impr_mf1_ctx-sens_stage1.pdf', dpi=300, bbox_inches='tight')

# %% [markdown]
# now I ran the experiments in STAGE2 modus (combined train and val set for training set, evaluation on hold-out test set)
# below I plot the performances for stage2

# %%
### run if you want the context-free model plot STAGE2 ###
PERF_DIR = PROJECT_ROOT / "reports" / "metrics"
with open(PERF_DIR / "ctxfree_finetuning_results_stage2.json", 'r') as f:
    res_finetuning_dict = json.load(f)
# print(res_finetuning_dict)
mf1_finetuned = []
for key in res_finetuning_dict:
    nested_dict = res_finetuning_dict[key]
    mf1_score = nested_dict['stage2_mf1']
    mf1_finetuned.append(mf1_score)
print(mf1_finetuned)

with open(PERF_DIR / "ctxfree_fullysupervised_results_stage2.json", 'r') as f:
    res_fullysuperv_dict = json.load(f)
# print(res_fullysuperv_dict)
mf1_fullysuperv = []
for key in res_fullysuperv_dict:
    nested_dict = res_fullysuperv_dict[key]
    mf1_score = nested_dict['stage2_mf1']
    mf1_fullysuperv.append(mf1_score)
print(mf1_fullysuperv)

# let's plot the results now
p = [0.01, 0.05, 0.1, 0.2, 0.5, 1.0]
p = [x * 100 for x in p]  # convert to percentage
plt.figure(figsize=(10, 6))
plt.plot(p, mf1_finetuned, marker='x', linewidth=2, markersize=8, label='SSL Pretrain + FT', color='green')
plt.plot(p, mf1_fullysuperv, marker='o', linewidth=2, markersize=8, label='Supervised from Scratch', color='red')
plt.xlabel('\nPercentage of labeled training data (%)\n', fontsize=18)
plt.ylabel('\nMacro F1 Score\n', fontsize=18)
# plt.title('Linear Probing vs. SSL Fine-Tuning vs. Fully-Supervised End-to-End\n', fontsize=18)
plt.legend(fontsize=16)
plt.tick_params(axis='both', labelsize=16)
plt.tight_layout()
plt.grid(True)
# plt.show()
plt.savefig(TARGET_DIR / 'finetuned_vs_fullysupervised_mf1_ctx-free_stage2.pdf', dpi=300, bbox_inches='tight')

# relative improvement plot stage2
p = [0.01, 0.05, 0.1, 0.2, 0.5, 1.0]
p_percent = [x * 100 for x in p]  # convert to percentage
rel_impr_finetuned =[]
for fine, fully in zip(mf1_finetuned, mf1_fullysuperv):
    rel_impr_finetuned.append((fine - fully) / fully * 100)
plt.figure(figsize=(10, 6))
plt.plot(p_percent, rel_impr_finetuned, marker='x', linewidth=2, markersize=8, color='green')
plt.xlabel('\nPercentage of labeled training data (%)\n', fontsize=18)
plt.ylabel('\nRelative Improvement MF1 Score (%)\n', fontsize=18)
plt.tick_params(axis='both', labelsize=16)
plt.tight_layout()
plt.grid(True)
# plt.show()
plt.savefig(TARGET_DIR / 'finetuned_vs_fullysupervised_rel_impr_mf1_ctx-free_stage2.pdf', dpi=300, bbox_inches='tight')

# plot the F1 Score for the individual sleep stages for varying p next to each other (STAGE2)
wake_finetuned, n1_finetuned, n2_finetuned, n3_finetuned, rem_finetuned = [], [], [], [], []
wake_fullysuperv, n1_fullysuperv, n2_fullysuperv, n3_fullysuperv, rem_fullysuperv = [], [], [], [], []
for key in res_finetuning_dict:
    nested_dict = res_finetuning_dict[key]
    per_class_f1 = nested_dict['stage2_per_class_f1']
    wake_finetuned.append(per_class_f1[0])
    n1_finetuned.append(per_class_f1[1])
    n2_finetuned.append(per_class_f1[2])
    n3_finetuned.append(per_class_f1[3])
    rem_finetuned.append(per_class_f1[4])
for key in res_fullysuperv_dict:
    nested_dict = res_fullysuperv_dict[key]
    per_class_f1 = nested_dict['stage2_per_class_f1']
    wake_fullysuperv.append(per_class_f1[0])
    n1_fullysuperv.append(per_class_f1[1])
    n2_fullysuperv.append(per_class_f1[2])
    n3_fullysuperv.append(per_class_f1[3])
    rem_fullysuperv.append(per_class_f1[4])

fig, axes = plt.subplots(1, 5, figsize=(26, 5))
stages = ['Wake', 'N1', 'N2', 'N3', 'REM']
finetuned_data = [wake_finetuned, n1_finetuned, n2_finetuned, n3_finetuned, rem_finetuned]
fullysuperv_data = [wake_fullysuperv, n1_fullysuperv, n2_fullysuperv, n3_fullysuperv, rem_fullysuperv]
for idx, (ax, stage, fine, fully) in enumerate(zip(axes, stages, finetuned_data, fullysuperv_data)):
    ax.set_title(f'{stage}', fontsize=16, fontweight='bold')
    ax.plot(p_percent, fine, marker='x', linewidth=2, markersize=8, color='green', label='SSL Pretrain + FT')
    ax.plot(p_percent, fully, marker='o', linewidth=2, markersize=8, color='red', label='Supervised from Scratch')
    ax.set_xlabel('\nPercentage of labeled training data (%)\n', fontsize=14)
    ax.set_ylabel(f'\nF1 Score\n', fontsize=14)
    ax.tick_params(axis='both', labelsize=12)
    ax.grid(True)
    if idx == 0: # only add legend to the first subplot
        ax.legend(fontsize=12)
plt.tight_layout()
plt.savefig(TARGET_DIR / 'finetuned_vs_fullysupervised_perclassf1_ctx-free_stage2_horizontal.pdf', dpi=300, bbox_inches='tight')
# Out:
# [0.5843932089755343, 0.6212564808998295, 0.6531289016632259, 0.6479347210670601, 0.6757851439289699, 0.6736423013682303]
# [0.47195613065765435, 0.5833049393547192, 0.6231662577130016, 0.6482700575046252, 0.6696465319607119, 0.7036646919979157]

# %%
### run if you want the context-sensitive model plots STAGE2 ###
PERF_DIR = PROJECT_ROOT / "reports" / "metrics"
with open(PERF_DIR / "ctxsensitive_finetuning_results_stage2.json", 'r') as f:
    res_finetuning_dict = json.load(f)
with open(PERF_DIR / "ctxsensitive_fullysupervised_results_stage2.json", 'r') as f:
    res_fullysuperv_dict = json.load(f)

mf1_finetuned = []
for key in res_finetuning_dict:
    nested_dict = res_finetuning_dict[key]
    mf1_score = nested_dict['stage2_mf1']
    mf1_finetuned.append(mf1_score)
    
mf1_fullysuperv = []
for key in res_fullysuperv_dict:
    nested_dict = res_fullysuperv_dict[key]
    mf1_score = nested_dict['stage2_mf1']
    mf1_fullysuperv.append(mf1_score)

# let's plot the results now
p = [0.01, 0.05, 0.1, 0.2, 0.5, 1.0]
p = [x * 100 for x in p]  # convert to percentage
plt.figure(figsize=(10, 6))
plt.plot(p, mf1_finetuned, marker='x', linewidth=2, markersize=8, label='SSL Pretrain + FT', color='green')
plt.plot(p, mf1_fullysuperv, marker='o', linewidth=2, markersize=8, label='Supervised from Scratch', color='red')
plt.xlabel('\nPercentage of labeled training data (%)\n', fontsize=18)
plt.ylabel('\nMacro F1 Score\n', fontsize=18)
# plt.title('Linear Probing vs. SSL Fine-Tuning vs. Fully-Supervised End-to-End\n', fontsize=18)
plt.legend(fontsize=16)
plt.tick_params(axis='both', labelsize=16)
plt.tight_layout()
plt.grid(True)
# plt.show()
plt.savefig(TARGET_DIR / 'finetuned_vs_fullysupervised_mf1_ctx-sensitive_stage2.pdf', dpi=300, bbox_inches='tight')


 # relative improvement plot stage2
p = [0.01, 0.05, 0.1, 0.2, 0.5, 1.0]
p_percent = [x * 100 for x in p]  # convert to percentage
rel_impr_finetuned =[]
for fine, fully in zip(mf1_finetuned, mf1_fullysuperv):
    rel_impr_finetuned.append((fine - fully) / fully * 100)
plt.figure(figsize=(10, 6))
plt.plot(p_percent, rel_impr_finetuned, marker='x', linewidth=2, markersize=8, color='green')
plt.xlabel('\nPercentage of labeled training data (%)\n', fontsize=18)
plt.ylabel('\nRelative Improvement MF1 Score (%)\n', fontsize=18)
plt.tick_params(axis='both', labelsize=16)
plt.tight_layout()
plt.grid(True)
# plt.show()
plt.savefig(TARGET_DIR / 'finetuned_vs_fullysupervised_rel_impr_mf1_ctx-sensitive_stage2.pdf', dpi=300, bbox_inches='tight')


# plot the F1 Score for the individual sleep stages for varying p next to each other (STAGE2)
wake_finetuned, n1_finetuned, n2_finetuned, n3_finetuned, rem_finetuned = [], [], [], [], []
wake_fullysuperv, n1_fullysuperv, n2_fullysuperv, n3_fullysuperv, rem_fullysuperv = [], [], [], [], []
for key in res_finetuning_dict:
    nested_dict = res_finetuning_dict[key]
    per_class_f1 = nested_dict['stage2_per_class_f1']
    wake_finetuned.append(per_class_f1[0])
    n1_finetuned.append(per_class_f1[1])
    n2_finetuned.append(per_class_f1[2])
    n3_finetuned.append(per_class_f1[3])
    rem_finetuned.append(per_class_f1[4])
for key in res_fullysuperv_dict:
    nested_dict = res_fullysuperv_dict[key]
    per_class_f1 = nested_dict['stage2_per_class_f1']
    wake_fullysuperv.append(per_class_f1[0])
    n1_fullysuperv.append(per_class_f1[1])
    n2_fullysuperv.append(per_class_f1[2])
    n3_fullysuperv.append(per_class_f1[3])
    rem_fullysuperv.append(per_class_f1[4])

# plot horizontally
fig, axes = plt.subplots(1, 5, figsize=(26, 5))
stages = ['Wake', 'N1', 'N2', 'N3', 'REM']
finetuned_data = [wake_finetuned, n1_finetuned, n2_finetuned, n3_finetuned, rem_finetuned]
fullysuperv_data = [wake_fullysuperv, n1_fullysuperv, n2_fullysuperv, n3_fullysuperv, rem_fullysuperv]
for idx, (ax, stage, fine, fully) in enumerate(zip(axes, stages, finetuned_data, fullysuperv_data)):
    ax.set_title(f'{stage}', fontsize=16, fontweight='bold')
    ax.plot(p_percent, fine, marker='x', linewidth=2, markersize=8, color='green', label='SSL Pretrain + FT')
    ax.plot(p_percent, fully, marker='o', linewidth=2, markersize=8, color='red', label='Supervised from Scratch')
    ax.set_xlabel('\nPercentage of labeled training data (%)\n', fontsize=14)
    ax.set_ylabel(f'\nF1 Score\n', fontsize=14)
    ax.tick_params(axis='both', labelsize=12)
    ax.grid(True)
    if idx == 0: # only add legend to the first subplot
        ax.legend(fontsize=12)
plt.tight_layout()
plt.savefig(TARGET_DIR / 'finetuned_vs_fullysupervised_perclassf1_ctx-sensitive_stage2_horizontal.pdf', dpi=300, bbox_inches='tight')

# # plot vertically
# fig, axes = plt.subplots(5, 1, figsize=(5, 20))
# stages = ['Wake', 'N1', 'N2', 'N3', 'REM']
# finetuned_data = [wake_finetuned, n1_finetuned, n2_finetuned, n3_finetuned, rem_finetuned]
# fullysuperv_data = [wake_fullysuperv, n1_fullysuperv, n2_fullysuperv, n3_fullysuperv, rem_fullysuperv]
# for idx, (ax, stage, fine, fully) in enumerate(zip(axes, stages, finetuned_data, fullysuperv_data)):
#     ax.set_title(f'{stage}', fontsize=16, fontweight='bold')
#     ax.plot(p_percent, fine, marker='x', linewidth=2, markersize=8, color='green', label='SSL Pretrain + FT')
#     ax.plot(p_percent, fully, marker='o', linewidth=2, markersize=8, color='red', label='Supervised from Scratch')
#     ax.set_xlabel('\nPercentage of labeled training data (%)\n', fontsize=14)
#     ax.set_ylabel(f'F1 Score\n', fontsize=14)
#     ax.tick_params(axis='both', labelsize=12)
#     ax.grid(True)
#     if idx == 0: # only add legend to the first subplot
#          ax.legend(fontsize=12)
# plt.tight_layout()
# plt.savefig(TARGET_DIR / 'finetuned_vs_fullysupervised_perclassf1_ctx-sensitive_stage2_vertical.pdf', dpi=300, bbox_inches='tight')

# plot 2x3 grid
fig, axes = plt.subplots(2, 3, figsize=(14, 8))
axes_flat = axes.flatten()
stages = ['Wake', 'N1', 'N2', 'N3', 'REM']
finetuned_data = [wake_finetuned, n1_finetuned, n2_finetuned, n3_finetuned, rem_finetuned]
fullysuperv_data = [wake_fullysuperv, n1_fullysuperv, n2_fullysuperv, n3_fullysuperv, rem_fullysuperv]
for idx, (ax, stage, fine, fully) in enumerate(zip(axes_flat[:5], stages, finetuned_data, fullysuperv_data)):
    ax.set_title(f'{stage}', fontsize=14, fontweight='bold')
    ax.plot(p_percent, fine, marker='x', linewidth=2, markersize=7, color='green', label='SSL Pretrain + FT')
    ax.plot(p_percent, fully, marker='o', linewidth=2, markersize=7, color='red', label='Supervised from Scratch')
    ax.set_xlabel('Percentage of labeled training data (%)', fontsize=12)
    ax.set_ylabel('F1 Score', fontsize=12)
    ax.tick_params(axis='both', labelsize=11)
    ax.grid(True)
    if idx == 0:
        ax.legend(fontsize=10)
axes_flat[5].axis('off')  # leave last subplot empty
plt.tight_layout()
plt.savefig(TARGET_DIR / 'finetuned_vs_fullysupervised_perclassf1_ctx-sensitive_stage2_grid.pdf', dpi=300, bbox_inches='tight')
